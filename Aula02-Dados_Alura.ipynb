# %% [markdown]
# # **Importando os dados usando o pandas. Seaborn e matplotlib para os gráficos**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# # **Renomeando a coluna "drogas" para "composto"**

# %%
mapa = {'droga': 'composto'}
dados.rename(columns = mapa, inplace = True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
cod_compostos = dados['composto'].value_counts().index[0:5]

# %%
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %% [markdown]
# # **Plotando um countplot em relação aos "compostos"**

# %%
sns.set()
plt.figure(figsize = (8, 6))

ax = sns.countplot(x = 'composto', data = dados.query('composto in @cod_compostos'))
ax.set_title('Top 5 Compostos')
plt.show() ###Retira algumas linhas específicas que ficam em cima do gráfico

# %%
len(dados['g-0'].unique()) ###14.367 dados únicos dentro do "g-0"
# Out:
# 14367

# %%
dados['g-0'].max() ###Valor máximo dentro do "g-0"
# Out:
# 10.0

# %%
dados['g-0'].min() ###Valor mínimo dentro do "g-0"
# Out:
# -5.513

# %%
dados['g-0'].mean() ###Valor médio do "g-0"
# Out:
# 0.24836629293692816

# %%
dados['g-0'].hist(bins = 50)
plt.show()

# %% [markdown]
# # **Usando o método .describe() para visualizar informações básicas**

# %%
dados.describe() ###metódo describe é usado para visualizar algumas estastísticas e detalhes básicos como %, média, std,etc ...
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados[['g-0', 'g-1']]
# Out:
#           g-0     g-1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
dados.loc[:, 'g-0':'g-771'].describe()
# Out:
#                 g-0           g-1  ...         g-770         g-771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %% [markdown]
# # **Plotando histogramas nas médias, mínimas e máximas**

# %%
dados.loc[:, 'g-0':'g-771'].describe().T['mean'].hist(bins = 30)
plt.show()

# %%
dados.loc[:, 'g-0':'g-771'].describe().T['min'].hist(bins = 30)
plt.show()

# %%
dados.loc[:, 'g-0':'g-771'].describe().T['max'].hist(bins = 30)
plt.show()

# %%
dados.loc[:, 'c-0':'c-99'].describe().T['mean'].hist(bins = 50)
plt.show()

# %%
sns.boxplot(x = 'g-0', data = dados)
plt.show()

# %%
plt.figure(figsize = (8, 6))
sns.boxplot(y = 'g-0', x = 'tratamento', data = dados)
plt.show()

# %% [markdown]
# # **01: Ordenar o gráfico countplot e melhorar a visualização alterando o tamanho da fonte.**
#
# Preferi por ordenar o gráfico em ordem crescente, já que por padrão ele ordena da forma decrescente.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
mapa = {'droga': 'composto'}
dados.rename(columns = mapa, inplace = True)

# %%
cod_compostos = dados['composto'].value_counts().index[0:5]

# %%
sns.set()
plt.figure(figsize = (8, 6))

ax = sns.countplot(x = 'composto', data = dados.query('composto in @cod_compostos'))
ax.set_title('Top 5 Compostos')
plt.show() ###Retira algumas linhas específicas que ficam em cima do gráfico

# %%
sns.set()
plt.figure(figsize = (8, 6))

ax = sns.countplot(x = 'composto', data = dados.query('composto in @cod_compostos'), order = reversed(dados['composto'].value_counts().index[0:5]))
###Usar o "order" sem passar o "reversed" antes irá mostrar um gráfico em order decrescente 
ax.set_xlabel('Compostos', fontsize = 10)
ax.set_ylabel('Quantidade', fontsize = 10)
ax.set_title('Top 5 Compostos mais utilizados')
plt.show()

# %% [markdown]
# # **02: Plotar os histogramas com seaborn**

# %%
dados.describe()
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados['g-0'].hist()
plt.show()

# %%
plt.figure(figsize = (15, 10))
dados['g-0'].hist(bins = 50)
plt.show()

# %%
fig, ax = plt.subplots(2, constrained_layout = True, figsize = (15, 8))

ax1 = sns.histplot(data = dados.loc[:, 'g-0': 'g-771'].describe().T['mean'], bins = 50, ax=ax[0], color = 'blue')
ax[0].set_xlabel('Média dos G', fontsize = 10)
ax[0].set_ylabel('Quantidade', fontsize = 10)
ax[0].set_title('Histograma do G', fontsize = 20)

ax1 = sns.histplot(data = dados.loc[:, 'c-0': 'c-99'].describe().T['mean'], bins = 50, ax=ax[1], color = 'purple')
ax[1].set_xlabel('Média dos C', fontsize = 10)
ax[1].set_ylabel('Quantidade dos C', fontsize = 10)
ax[1].set_title('Histograma dos C', fontsize = 20)

plt.show()

# %% [markdown]
# O comando fig, ax = plt.subplots(2, constrained_layout=True, figsize =(20,8)) nos faz primeiro dizer que é uma fig, após o nome do array, com isso você cria subplots e passa por parametro a quantidade de plots, o constrained_layout=True para ajuste e p figsize para o tamanho do histograma.

# %% [markdown]
# # **03: Estudar sobre as estatísticas retornadas no .describe()**

# %%
dados.describe()
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %% [markdown]
# Usando o .describe(), ele nos retorna algumas informações básicas como:
# a quantidade(count), a média(mean), o desvio padrão(std), o número mínimo, o primeiro quartil(25%), a mediana(50%), o terceiro quartil(75%) e o número máximo

# %% [markdown]
# # **04: A importância da manipulação dos tamanhos das visualizações dos dados**

# %% [markdown]
# Fazer o uso de gráficos e diagramas ajuda o cérebro na visualizações e no entedimento dos dados, sendo mais fácil do que se somente jogar as informações em relatórios ou planilhas.
#
# A visualizações de dados também pode nos indicar quais áreas precisam de melhoria, ajuda a entender quais os fatores que influenciam os consumidores, ajuda a prever o volume de vendas, entre tantas outras vantagens.

# %% [markdown]
# ##Aula2
# ###Challenges: Ordenar o gráfico countplot e melhorar a visualização alterando o tamanho da fonte. ✔
#
#
# ---
#
#
# ###Challenges: Plotar os histogramas com seaborn ✔
#
#
# ---
#
#
# ###Challenges: Estudar sobre as estatísticas retornadas no .describe() ✔
#
#
# ---
#
#
# ###Challenges: Refletir sobre a manipulação dos tamanhos das visualizações.
#
#
# ---
#
#
# ###Challenges: Fazer outras análises com o boxplot e até com o histograma. --> Ver documentação para plotar mais de um histograma na mesma figura

# %% [markdown]
# # **05: Fazer outras análises com o boxplot e histogramas**

# %%
fig, ax = plt.subplots(3, constrained_layout = True, figsize = (10, 15))

ax1 = sns.boxplot(x = 'g-5', y = 'tratamento', data = dados, ax=ax[0], color = 'slateblue')
ax[0].set_xlabel('g-5', fontsize = 15)
ax[0].set_ylabel('Tratamentos', fontsize = 15)
ax[0].set_title('Tratamentos', fontsize = 20)

ax2 = sns.boxplot(x = 'g-5', y = 'dose', data = dados, ax=ax[1], color = 'gold')
ax[1].set_xlabel('g-5', fontsize = 15)
ax[1].set_ylabel('Doses', fontsize = 15)
ax[1].set_title('Doses', fontsize = 20)

ax3 = sns.boxplot(x = 'tempo', y = 'g-5', data = dados, ax=ax[2], color = 'turquoise')
ax[2].set_xlabel('Tempo', fontsize = 15)
ax[2].set_ylabel('g-5', fontsize = 15)
ax[2].set_title('Tempo', fontsize = 20)
plt.show()

# %% [markdown]
# Acima podemos ver os boxplots do tratamento, dose e tempo, respectivamente.

# %%
fig, ax = plt.subplots(2, constrained_layout = True, figsize = (15, 8))

ax1 = sns.histplot(data = dados.loc[:, 'g-0': 'g-771'].describe().T['mean'], bins = 50, ax=ax[0], color = 'olive')
ax[0].set_xlabel('Média dos G', fontsize = 10)
ax[0].set_ylabel('Quantidade', fontsize = 10)
ax[0].set_title('Histograma do G', fontsize = 20)

ax1 = sns.histplot(data = dados.loc[:, 'c-0': 'c-99'].describe().T['mean'], bins = 50, ax=ax[1], color = 'orange')
ax[1].set_xlabel('Média dos C', fontsize = 10)
ax[1].set_ylabel('Quantidade dos C', fontsize = 10)
ax[1].set_title('Histograma dos C', fontsize = 20)

plt.show()
