# %% [markdown]
# # **Aula 04 - Importando toda a base dados**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['acat_inhibitor'].unique()
# Out:
# array([0, 1])

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %%
contagem_moa = dados_resultados.select_dtypes('int64').sum().sort_values(ascending = False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %% [markdown]
# .select_dtype('int64') ele seleciona apenas os numeros inteiros

# %%
dados_resultados.drop('id', axis = 1).sum(axis = 1)

###na primeira linha houve a ativação de um mecanimos de ação, na terceira linha houve 3 mecanismos ativados
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Faremos aqui um merge (serve para juntar duas bases de dados) entre os dados de tratamento e os dados de resultados

# %%
dados_resultados['n_moa'] != 0
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 23809     True
# 23810     True
# 23811    False
# 23812     True
# 23813    False
# Name: n_moa, Length: 23814, dtype: bool

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id', axis = 1).sum(axis = 1)

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      2       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      6       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      2       True
#
# [5 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id','n_moa', 'ativo_moa']], on = 'id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      2       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      6       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      2       True
#
# [5 rows x 879 columns]

# %% [markdown]
# # **Encontrar o Top 10 das ações do MOA (inibidor, agonist, etc ...)**

# %%
moa_tabela = dados_resultados.drop(['id', 'n_moa', 'ativo_moa'], axis = 1).sum().sort_values(ascending = True)
moa_tabela
# Out:
# atp-sensitive_potassium_channel_antagonist      1
# erbb2_inhibitor                                 1
# diuretic                                        6
# autotaxin_inhibitor                             6
# protein_phosphatase_inhibitor                   6
#                                              ...
# serotonin_receptor_antagonist                 404
# dopamine_receptor_antagonist                  424
# cyclooxygenase_inhibitor                      435
# proteasome_inhibitor                          726
# nfkb_inhibitor                                832
# Length: 206, dtype: int64

# %% [markdown]
# Mostramos somente os resultados mais recorrentes
#
# .select_dtype() ele seleciona apenas os dados que desejamos realizar a função
#
# .sort_values() realiza a ordenação dos valores, o parâmetro passado pode ser tanto "ascending = True ou ascending = False", ordenar em ordem crescente ou decrescente, respectivamente.

# %%
split_nome = [cont.split('_')[-1]for cont in moa_tabela.index]
split_nome[:10]
# Out:
# ['antagonist',
#  'inhibitor',
#  'diuretic',
#  'inhibitor',
#  'inhibitor',
#  'antiarrhythmic',
#  'antagonist',
#  'agonist',
#  'inhibitor',
#  'inhibitor']

# %% [markdown]
# Dividi-se a string usando o split(), no parâmetro passa-se qual caracter que será dividido

# %%
tabela_nova = pd.DataFrame(data = {'Moa':moa_tabela.index, 'Contagem':moa_tabela.values, 'Ação': split_nome})
tabela_nova
# Out:
#                                             Moa  Contagem        Ação
# 0    atp-sensitive_potassium_channel_antagonist         1  antagonist
# 1                               erbb2_inhibitor         1   inhibitor
# 2                                      diuretic         6    diuretic
# 3                           autotaxin_inhibitor         6   inhibitor
# 4                 protein_phosphatase_inhibitor         6   inhibitor
# ..                                          ...       ...         ...
# 201               serotonin_receptor_antagonist       404  antagonist
# 202                dopamine_receptor_antagonist       424  antagonist
# 203                    cyclooxygenase_inhibitor       435   inhibitor
# 204                        proteasome_inhibitor       726   inhibitor
# 205                              nfkb_inhibitor       832   inhibitor
#
# [206 rows x 3 columns]

# %%
Tabela_top10 = tabela_nova.groupby(by = ['Ação']).sum()['Contagem'].sort_values(ascending = False).reset_index()[:10]
Tabela_top10.columns = ['Moa', 'Quantidade']
Top10 = tabela_nova.groupby(by = ['Ação']).sum()['Contagem'].sort_values(ascending = False)[:10]
Tabela_top10
# Out:
#                  Moa  Quantidade
# 0          inhibitor        9693
# 1         antagonist        3449
# 2            agonist        2330
# 3            blocker         323
# 4              agent         150
# 5          activator         115
# 6              local          80
# 7  immunosuppressant          73
# 8  anti-inflammatory          73
# 9        antioxidant          73

# %%
sns.set()
plt.figure(figsize=(12,8))
plt.xlabel('Ação', fontsize = 12)
plt.ylabel('Quantidade', fontsize = 12)
plt.title('Top 10 Ações MOA', fontsize = 12)
Top10.plot.bar()
plt.show()

# %% [markdown]
# # **Criar a coluna eh_controle para quando na linha tratamento == com_controle**

# %%
coluna_nova = dados_combinados['tratamento'] == 'com_controle'
coluna_nova
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23809    False
# 23810    False
# 23811     True
# 23812    False
# 23813    False
# Name: tratamento, Length: 23814, dtype: bool

# %% [markdown]
# Após selecionar todas as linhas que o tratamento foi feito com controle o resultado será True, se não for feito o controle será False o resultado mostrado

# %%
dados_combinados['eh_controle'] = coluna_nova
dados_combinados

#É possível ainda substituir o True/False da nova coluna criada pelo 1 e 0, usando o comando astype('int'), ficando assim:
#dados_combinados['eh_controle'] = coluna_nova.astype('int')
#dados_combinados
# Out:
#                  id    tratamento  tempo  ... n_moa ativo_moa  eh_controle
# 0      id_000644bb2     com_droga     24  ...     2      True        False
# 1      id_000779bfc     com_droga     72  ...     0     False        False
# 2      id_000a6266a     com_droga     48  ...     6      True        False
# 3      id_0015fd391     com_droga     48  ...     0     False        False
# 4      id_001626bd3     com_droga     72  ...     2      True        False
# ...             ...           ...    ...  ...   ...       ...          ...
# 23809  id_fffb1ceed     com_droga     24  ...     2      True        False
# 23810  id_fffb70c0c     com_droga     24  ...     2      True        False
# 23811  id_fffc1c3f4  com_controle     48  ...     0     False         True
# 23812  id_fffcb9e7c     com_droga     24  ...     2      True        False
# 23813  id_ffffdd77b     com_droga     72  ...     0     False        False
#
# [23814 rows x 880 columns]

# %% [markdown]
# # **Criar 3 colunas para indicar o tempo 24h, 48h e 72h**

# %%
H24 = dados_combinados['tempo'] == 24
H24
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23809     True
# 23810     True
# 23811    False
# 23812     True
# 23813    False
# Name: tempo, Length: 23814, dtype: bool

# %%
H48 = dados_combinados['tempo'] == 48
H48
# Out:
# 0        False
# 1        False
# 2         True
# 3         True
# 4        False
#          ...
# 23809    False
# 23810    False
# 23811     True
# 23812    False
# 23813    False
# Name: tempo, Length: 23814, dtype: bool

# %%
H72 = dados_combinados['tempo'] == 72
H72
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 23809    False
# 23810    False
# 23811    False
# 23812    False
# 23813     True
# Name: tempo, Length: 23814, dtype: bool

# %%
dados_combinados['24 Horas'] = H24
dados_combinados['48 Horas'] = H48
dados_combinados['72 Horas'] = H72
dados_combinados

#É possível ainda substituir o True/False da nova coluna criada pelo 1 e 0, usando o comando astype('int'), ficando assim:dados_combinados['24 Horas'] = H24
#dados_combinados['24 Horas'] = H24.astype('int)
#dados_combinados['48 Horas'] = H48.astype('int)
#dados_combinados['72 Horas'] = H72.astype('int)
#dados_combinados
# Out:
#                  id    tratamento  tempo  ... 24 Horas 48 Horas  72 Horas
# 0      id_000644bb2     com_droga     24  ...     True    False     False
# 1      id_000779bfc     com_droga     72  ...    False    False      True
# 2      id_000a6266a     com_droga     48  ...    False     True     False
# 3      id_0015fd391     com_droga     48  ...    False     True     False
# 4      id_001626bd3     com_droga     72  ...    False    False      True
# ...             ...           ...    ...  ...      ...      ...       ...
# 23809  id_fffb1ceed     com_droga     24  ...     True    False     False
# 23810  id_fffb70c0c     com_droga     24  ...     True    False     False
# 23811  id_fffc1c3f4  com_controle     48  ...    False     True     False
# 23812  id_fffcb9e7c     com_droga     24  ...     True    False     False
# 23813  id_ffffdd77b     com_droga     72  ...    False    False      True
#
# [23814 rows x 883 columns]

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()

###Precisa passar em aspas duplas, já que definimos a query em aspas simples
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
composto_principal = dados_combinados['droga'].value_counts().index[:5]
plt.figure(figsize = (12, 8))
sns.boxplot(data = dados_combinados.query('droga in @composto_principal'), y = 'g-0', x = 'droga', hue = 'ativo_moa')
plt.show()
