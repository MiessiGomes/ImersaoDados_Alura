# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
dados = pd.read_csv(url_dados, compression = 'zip')

dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id', axis = 1).sum(axis = 1)

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id', 'n_moa', 'ativo_moa']], on = 'id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
from sklearn.model_selection import train_test_split

#Ele retorna o "x_treino e x_teste", "y_treino e y_teste"


x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2)

# %%
#Modelo de Regressão Logística
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split


x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify = y, random_state = 23456)
#Usa-se o random_state para diminuir a discrepância do valor gerado pelo treino, ou seja, diminuir a variação da % de acerto


modelo_rLogistica = LogisticRegression(max_iter = 1000)
modelo_rLogistica.fit(x_treino, y_treino)
modelo_rLogistica.score(x_teste, y_teste)

#Precisamos separar um conjunto de dados para treino e outro para testes
# Out:
# 0.6306949401637624

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score


modelo_dummy = DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino, y_treino)
previsao_dummy = modelo_dummy.predict(x_teste)
accuracy_score(y_teste, previsao_dummy)
# Out:
# 0.6067604450976275

# %%
dados_combinados['ativo_moa'].value_counts(normalize = True)
# Out:
# True     0.60666
# False    0.39334
# Name: ativo_moa, dtype: float64

# %%
#Treinando um terceiro modelo que será uma árvore de decisão

from sklearn.tree import DecisionTreeClassifier

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify = y, random_state = 23456)

modelo_arvore = DecisionTreeClassifier(max_depth = 3)
modelo_arvore.fit(x_treino, y_treino)
modelo_arvore.score(x_teste, y_teste)
# Out:
# 0.6269158093638463

# %%
from sklearn import tree

fig, ax = plt.subplots(figsize=(15, 10), facecolor = 'w')
tree.plot_tree(modelo_arvore,
               ax = ax,
               fontsize = 10,
               rounded = True,
               filled = True,
               feature_names = x_treino.columns,
               class_names = ['Não Ativado', 'Ativado'])
plt.show()

# %% [markdown]
# A partir do gene 385 ele divide a árvore em dois e o objetivo desta divisão é ter os lados o mais homogêneo possível.
#
# Quando chegar no último nível que são as folhas, ele realiza a classificação (class), se ele foi ativo ou não foi ativo

# %%
from sklearn.tree import DecisionTreeClassifier

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify = y, random_state = 23456)

teste = []
treino = []
for i in range(1, 15):
    modelo_arvore = DecisionTreeClassifier(max_depth = i)
    modelo_arvore.fit(x_treino, y_treino)
    teste.append(modelo_arvore.score(x_teste, y_teste))
    treino.append(modelo_arvore.score(x_treino, y_treino))

# %%
teste
# Out:
# [0.6067604450976275,
#  0.6067604450976275,
#  0.6269158093638463,
#  0.6275456644971656,
#  0.6321646021415075,
#  0.6313247952970816,
#  0.6393029603191266,
#  0.633844215830359,
#  0.6285954230526979,
#  0.6237665336972497,
#  0.6269158093638463,
#  0.6195674994751207,
#  0.614948561830779,
#  0.6153684652529918]

# %%
treino
# Out:
# [0.6066348223190384,
#  0.6071072384651724,
#  0.6164505800220461,
#  0.6327751824051231,
#  0.6390215736706735,
#  0.6474725736181828,
#  0.6553986667366543,
#  0.6665791821951603,
#  0.6774447535562438,
#  0.6924045981838224,
#  0.7117736601753188,
#  0.724161461340612,
#  0.745105243819222,
#  0.7651041940055641]

# %%
sns.lineplot(x = range(1,15), y = teste, label = 'teste')
sns.lineplot(x = range(1,15), y = treino, label = 'treino')
plt.show()

# %% [markdown]
# Como pode-se observar, a árvore de teste começa com um resultado bom e conforme o passar do tempo ele vai diminuindo, já na árvore de treino o resultado é completamento o oposto. Começando nos 60% de acerto, assim como no teste, porém, indo até 76% de acerto
#
# Porém aqui temos um problema de overfitting, onde o modelo é muito bom em se ajustar ao conjunto de dados anteriormente observado, porém ela se torna ruim em prever novos resultados.
#
# Para contornar esse problema podemos usar um modelo chamado Random Forest

# %%
pd.get_dummies(dados_combinados['tratamento'])
# Out:
#        com_controle  com_droga
# 0                 0          1
# 1                 0          1
# 2                 0          1
# 3                 0          1
# 4                 0          1
# ...             ...        ...
# 23809             0          1
# 23810             0          1
# 23811             1          0
# 23812             0          1
# 23813             0          1
#
# [23814 rows x 2 columns]

# %%
pd.get_dummies(dados_combinados, columns = ['tratamento', 'dose', 'tempo'])
# Out:
#                  id      droga     g-0  ...  tempo_24  tempo_48  tempo_72
# 0      id_000644bb2  b68db1d53  1.0620  ...         1         0         0
# 1      id_000779bfc  df89a8e5a  0.0743  ...         0         0         1
# 2      id_000a6266a  18bb41b2c  0.6280  ...         0         1         0
# 3      id_0015fd391  8c7f86626 -0.5138  ...         0         1         0
# 4      id_001626bd3  7cbed3131 -0.3254  ...         0         0         1
# ...             ...        ...     ...  ...       ...       ...       ...
# 23809  id_fffb1ceed  df1d0a5a1  0.1394  ...         1         0         0
# 23810  id_fffb70c0c  ecf3b6b74 -1.3260  ...         1         0         0
# 23811  id_fffc1c3f4  cacb2b860  0.3942  ...         0         1         0
# 23812  id_fffcb9e7c  8b87a7a83  0.6660  ...         1         0         0
# 23813  id_ffffdd77b  972f41291 -0.8598  ...         0         0         1
#
# [23814 rows x 883 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'droga'], axis = 1)
x = pd.get_dummies(x, columns = ['tratamento', 'dose', 'tempo'])
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify = y, random_state = 23456)

modelo_RandomForest = RandomForestClassifier()
modelo_RandomForest.fit(x_treino, y_treino)
modelo_RandomForest.score(x_teste, y_teste)
# Out:
# 0.6840226747847995

# %% [markdown]
# Para prevenir o problema do Overfitting usamos o RandomForest
